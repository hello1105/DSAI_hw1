# %%
#python=3.6
#tensorflow=1.15.0
#keras=2.3.1

# %%
# Import the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Import the training set
training_data = pd.read_csv('data.csv')

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler(feature_range = (0, 1))
training_data = sc.fit_transform(training_data)

# %%
train_in = []
train_out = []

k = 30

for i in range(k, len(training_data)): 
    train_in.append(training_data[i-k:i,:])
    train_out.append(training_data[i,:])
train_in = np.array(train_in)
train_out = np.array(train_out)

# %%
# Import the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Initialising the RNN
regressor = Sequential()

# %%
# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 64, return_sequences = True, input_shape = (train_in.shape[1], train_in.shape[2])))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 64, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 64, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 64))
regressor.add(Dropout(0.2))

# %%
# Adding the output layer
regressor.add(Dense(units = train_in.shape[2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eb41100d20e9> in <module>
#       1 # Adding the output layer
# ----> 2 regressor.add(Dense(units = train_in.shape[2], output_shape = (7)))
#
# NameError: name 'regressor' is not defined

# %%
from tensorflow import keras
from keras import backend as K

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 
    
# Compiling
regressor.compile(optimizer = "adam", loss = root_mean_squared_error)

# 進行訓練
regressor.fit(train_in, train_out, epochs = 2000, batch_size = 128)
# Out:
# Epoch 1/2000
# 570/570 [==============================] - 2s 4ms/step - loss: 0.3932
# Epoch 2/2000
# 570/570 [==============================] - 0s 677us/step - loss: 0.2269
# Epoch 3/2000
# 570/570 [==============================] - 0s 672us/step - loss: 0.1963
# Epoch 4/2000
# 570/570 [==============================] - 0s 679us/step - loss: 0.1790
# Epoch 5/2000
# 570/570 [==============================] - 0s 668us/step - loss: 0.1689
# Epoch 6/2000
# 570/570 [==============================] - 0s 665us/step - loss: 0.1599
# Epoch 7/2000
# 570/570 [==============================] - 0s 658us/step - loss: 0.1568
# Epoch 8/2000
# 570/570 [==============================] - 0s 646us/step - loss: 0.1485
# Epoch 9/2000
# 570/570 [==============================] - 0s 667us/step - loss: 0.1496
# Epoch 10/2000
# 570/570 [==============================] - 0s 679us/step - loss: 0.1452
# Epoch 11/2000
# 570/570 [==============================] - 0s 686us/step - loss: 0.1466
# Epoch 12/2000
# ...

# %%
testing_data = pd.read_csv('test.csv')
testing_data = testing_data.iloc[:, :].values
testing_data = sc.transform(testing_data)
testing_data = np.append(training_data[-k:], testing_data, axis=0)
real_data = sc.inverse_transform(testing_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fe285ee20c16> in <module>
# ----> 1 testing_data = pd.read_csv('test.csv')
#       2 testing_data = testing_data.iloc[:, :].values
#       3 testing_data = sc.transform(testing_data)
#       4 testing_data = np.append(training_data[-k:], testing_data, axis=0)
#       5 real_data = sc.inverse_transform(testing_data)
#
# NameError: name 'pd' is not defined

# %%
test_in = []
for i in range(k, len(testing_data)):
    test_in.append(testing_data[i-k:i, :])
test_in = np.array(test_in)

# %%
predicted_data = regressor.predict(test_in)
predicted_data = sc.inverse_transform(predicted_data)

# %%
# Visualising the results
plt.plot(real_data[k:,0], color = 'red', label = 'Real')
plt.plot(predicted_data[:,0], color = 'blue', label = 'Predicted')
plt.title('Prediction')
plt.xlabel('Time')
plt.ylabel('Load')
plt.legend()
plt.show()

plt.plot(real_data[k:,1], color = 'red', label = 'Real')
plt.plot(predicted_data[:,1], color = 'blue', label = 'Predicted')
plt.title('Prediction')
plt.xlabel('Time')
plt.ylabel('reverse')
plt.legend()
plt.show()

plt.plot(real_data[k:,2], color = 'red', label = 'Real')
plt.plot(predicted_data[:,2], color = 'blue', label = 'Predicted')
plt.title('Prediction')
plt.xlabel('Time')
plt.ylabel('reverse')
plt.legend()
plt.show()
